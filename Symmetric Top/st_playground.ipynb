# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import brentq
import matplotlib.animation as animation
from symmetric_top import rk4_4, f1, f2, f3, f4, runrk4, rk4anim, rk4graph1, rk4graph, crosses_zero, small, make_df_range
# Out:
# 2.07552e+00 1.56777e+00
# 1.34821e+00 2.76454e+00
# 1.42266e+00 5.64692e+00
# 2.47913e+00 3.96023e+00
# 1.30564e+00 3.13529e-01

# %%
x0 = 3*np.pi/4  # Example initial condition
p1_list = np.arange(-50,-30,1)  # Different p1 values
num_graphs = len(p1_list)

rk4graph(x0, p1_list, num_graphs)

# %%
rk4graph1(3*np.pi/4,-17)

# %%
rk4anim(np.pi/4,-17,100, name = "example.gif")
